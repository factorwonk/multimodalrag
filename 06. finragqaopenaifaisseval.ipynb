# %%
import os
import json
import pandas as pd
import ast
import numpy as np
import faiss
import torch
import math
import re

from typing import List, Dict, Any, Tuple
from IPython.display import Markdown, display, update_display
from dotenv import load_dotenv
from tqdm import tqdm
from transformers import pipeline
from transformers import AutoTokenizer, AutoModel, AutoModelForSeq2SeqLM
from sklearn.model_selection import train_test_split
from rouge_score import rouge_scorer
from openai import OpenAI

# %%
pd.set_option('display.width', -1)
pd.set_option('max_colwidth', 1000)

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
openai = OpenAI()
# Out:
# API key looks good so far

# %%
client = OpenAI(api_key=os.environ['OPENAI_API_KEY'])

# %% [markdown]
# ### 1. Load and Flattion ConvFinQA JSON data
# ---

# %%
def convfinqadfloader(filepath: str, max_rows: int = 1000) -> pd.DataFrame:
    with open(filepath, 'r', encoding='utf-8') as file:
        data = json.load(file)
    
    if max_rows is not None:
        data = data[:max_rows]
    
    flattened_data = []
    
    for item in data:
        base_item = {
            'id': item.get('id'),
            'pre_text': ' '.join(item.get('pre_text', [])),
            'post_text': ' '.join(item.get('post_text', [])),
            'filename': item.get('filename'),
            'table': str(item.get('table')),
        }
        
        annotation = item.get('annotation', {})
        if isinstance(annotation, dict):
            dialogue_break = annotation.get('dialogue_break', [])
            turn_program = annotation.get('turn_program', [])
            qa_split = annotation.get('qa_split', [])
            exe_ans_list = annotation.get('exe_ans_list', [])
            for idx in range(len(dialogue_break)):
                turn_data = {
                    'dialogue_text': dialogue_break[idx] if idx < len(dialogue_break) else None,
                    'turn_program': turn_program[idx] if idx < len(turn_program) else None,
                    'qa_split': qa_split[idx] if idx < len(qa_split) else None,
                    'execution_answer': exe_ans_list[idx] if idx < len(exe_ans_list) else None,
                    'turn_index': idx
                }
                combined_data = {**base_item, **turn_data}
                flattened_data.append(combined_data)
        
        if 'qa' in item:
            qa_data = {
                'question': item['qa'].get('question'),
                'answer': item['qa'].get('answer'),
                'explanation': item['qa'].get('explanation'),
                'program': item['qa'].get('program'),
                'execution_answer': item['qa'].get('exe_ans'),
                'turn_index': 0
            }
            combined_data = {**base_item, **qa_data}
            flattened_data.append(combined_data)
    
    df = pd.DataFrame(flattened_data)
    
    numeric_columns = ['turn_index', 'qa_split', 'execution_answer']
    for col in numeric_columns:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')
    return df

# %%
# Load data
df = convfinqadfloader("data/convfinqatrain.json")
print("Dataset loaded. Number of examples:", len(df))
# Out:
# Dataset loaded. Number of examples: 4378

# %% [markdown]
# ### 2. Create Combined Text Field
# ---

# %%
def create_combined_text(row):
    """
    Combine key text fields to form a context string.
    Uses 'pre_text', 'dialogue_text', 'post_text', 'execution_answer', and 'question' (if available).
    """
    texts = []
    if pd.notnull(row.get('pre_text')):
        texts.append("Pre-Text: " + row['pre_text'])
    if pd.notnull(row.get('dialogue_text')):
        texts.append("Dialogue: " + row['dialogue_text'])
    if pd.notnull(row.get('post_text')):
        texts.append("Post-Text: " + row['post_text'])
    if pd.notnull(row.get('execution_answer')):
        texts.append("Execution Answer: " + str(row['execution_answer']))
    if pd.notnull(row.get('question')):
        texts.append("Question: " + row['question'])
    return " | ".join(texts)

df['combined_text'] = df.apply(create_combined_text, axis=1)

# %% [markdown]
# ### 3. Chunking
# ---

# %%
def chunk_text(text, chunk_size=200, chunk_overlap=100):
    """
    Split a text into chunks of words with specified chunk size and overlap.
    """
    words = text.split()
    chunks = []
    start = 0
    while start < len(words):
        chunk = " ".join(words[start: start + chunk_size])
        chunks.append(chunk)
        if start + chunk_size >= len(words):
            break
        start += (chunk_size - chunk_overlap)
    return chunks

# %%
# Use a subset of the data (e.g., first 500 documents)
subset_df = df.iloc[:500].copy()

# %%
chunk_records = []
for idx, row in subset_df.iterrows():
    chunks = chunk_text(row['combined_text'], chunk_size=200, chunk_overlap=100)
    for i, chunk in enumerate(chunks):
        chunk_records.append({
            "doc_id": row['id'],
            "chunk_text": chunk,
            "turn_index": row.get('turn_index', None)
        })

# %%
chunk_df = pd.DataFrame(chunk_records)
print(f"Created {len(chunk_df)} chunks from {len(subset_df)} documents.")
# Out:
# Created 3019 chunks from 500 documents.

# %% [markdown]
# ### 4. OpenAI Embeddings
# ---

# %%
# Use OpenAI's ada-002 embeddings
def get_embedding(text, model="text-embedding-ada-002"):
    response = client.embeddings.create(input=[text], model=model)
    return np.array(response.data[0].embedding, dtype=np.float32)

# %%
def compute_embeddings(texts, engine="text-embedding-ada-002"):
    embeddings = []
    for text in texts:
        emb = get_embedding(text, model=engine)
        embeddings.append(emb)
    return np.vstack(embeddings)

# %% [markdown]
# Create embeddings on chunked documents ~ 20 minutes

# %%
# Compute embeddings for all chunks
chunk_texts = chunk_df['chunk_text'].tolist()
print("Computing embeddings for {} chunks...".format(len(chunk_texts)))
document_embeddings = compute_embeddings(chunk_texts)
embedding_dim = document_embeddings.shape[1]
# Out:
# Computing embeddings for 3019 chunks...

# %%
print("Done!")
# Out:
# Done!

# %% [markdown]
# ### 5. Create FAISS Index
# ---

# %%
faiss.normalize_L2(document_embeddings)

# %%
index = faiss.IndexFlatIP(embedding_dim)
index.add(document_embeddings)
print("FAISS index built with {} vectors.".format(index.ntotal))
# Out:
# FAISS index built with 3019 vectors.

# %%
def query_dataset(query, top_n=3, engine="text-embedding-ada-002"):
    query_embedding = get_embedding(query, model=engine).reshape(1, -1)
    faiss.normalize_L2(query_embedding)
    distances, indices = index.search(query_embedding, top_n)
    results = chunk_df.iloc[indices[0]].copy()
    results['score'] = distances[0]
    return results

# %% [markdown]
# ### 6. Generation with GPT-4o-mini
# ---

# %%
def generate_answer(query, context_docs, max_tokens=200, temperature=0.0, top_p=1.0):
    """
    Generate an answer by combining the query with retrieved context using GPT-4o-mini.
    The system prompt instructs the model to act as a friendly financial analyst bot that does not
    make up answers and only uses the provided data to answer numerical questions.
    """
    
    # Combine the retrieved context documents into a single string.
    context = "\n".join(context_docs)
    
    # Create a messages list with a system prompt and the user's prompt.
    messages = [
         {
             "role": "system",
             "content": "You are a friendly financial analyst bot. When given a question and context, you respond with only a single floating point number (and nothing else), which is the answer based solely on the provided data."
         },
         {
             "role": "user",
             "content": f"Question: {query}\nContext: {context}\nAnswer (only a number):"
         }
    ]
    response = openai.chat.completions.create(
         model="gpt-4o-mini",
         messages=messages,
         max_tokens=max_tokens,
         temperature=temperature,
         top_p=top_p,
         n=1,
         stop=["\n"]
    )
    return response.choices[0].message.content.strip()

# %% [markdown]
# ### 7. Train Test Split and Evaluation Setup
# ---

# %%
# For evaluation, use only examples with valid 'question' and 'execution_answer'
eval_df = df[(df['execution_answer'].notna()) & (df['question'].notna())].copy()
print(f"Evaluation dataset size: {len(eval_df)}")
# Out:
# Evaluation dataset size: 714

# %%
# 80:20 train-test split (we'll use the test set for evaluation)
_, test_df = train_test_split(eval_df, test_size=0.2, random_state=42)
print(f"Test set size: {len(test_df)}")
# Out:
# Test set size: 143

# %%
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# %% [markdown]
# ### 8. Evaluation Loop (Numeric Answers)
# ---

# %%
total_correct = 0
total_retrieval_precision = 0.0
total_rouge1 = 0.0
total_rouge2 = 0.0
total_rougeL = 0.0
num_evaluated = 0
tolerance = 1e-2  # Tolerance for numeric comparison

# %%
for idx, row in test_df.iterrows():
    query_text = row['question']
    
    # Convert ground truth to float
    try:
        ground_truth = float(row['execution_answer'])
    except Exception as e:
        continue  # Skip if conversion fails
    
    retrieved = query_dataset(query_text, top_n=3)
    context_docs = retrieved['chunk_text'].tolist()
    
    generated_text = generate_answer(query_text, context_docs, max_tokens=200, temperature=0.0, top_p=1.0).strip()
    
    try:
        generated_val = float(generated_text)
    except Exception as e:
        generated_val = None
    
    if generated_val is not None and math.isclose(generated_val, ground_truth, rel_tol=tolerance):
        total_correct += 1
        
    relevant_count = sum(1 for x in retrieved['doc_id'] if x == row['id'])
    retrieval_precision = relevant_count / len(retrieved) if len(retrieved) > 0 else 0.0
    total_retrieval_precision += retrieval_precision
    
    gt_str = f"{ground_truth:.2f}"
    gen_str = f"{generated_val:.2f}" if generated_val is not None else ""
    rouge_scores = scorer.score(gt_str, gen_str)
    total_rouge1 += rouge_scores['rouge1'].fmeasure
    total_rouge2 += rouge_scores['rouge2'].fmeasure
    total_rougeL += rouge_scores['rougeL'].fmeasure
    
    num_evaluated += 1
    
    print(f"Example {idx}:")
    print(f"Question: {query_text}")
    print(f"Ground Truth: {ground_truth}")
    print(f"Generated: {generated_text} (parsed as {generated_val})")
    print(f"Retrieval Precision: {retrieval_precision:.3f}")
    print(f"ROUGE-1: {rouge_scores['rouge1'].fmeasure:.3f}, ROUGE-2: {rouge_scores['rouge2'].fmeasure:.3f}, ROUGE-L: {rouge_scores['rougeL'].fmeasure:.3f}")
    print("----------\n")
# Out:
# Example 698:
# Question: what were total r&e expenses in millions for 2017 , 2016 and in 2015?
# Ground Truth: 581.0
# Generated: 72.0 (parsed as 72.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2048:
# Question: what is the total sublease revenue , in millions , from 2008-2010?
# Ground Truth: 18.2
# Generated: 31.2 (parsed as 31.2)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 230:
# Question: by how much did total other income and expense decrease from 2008 to 2009?
# Ground Truth: 0.47419
# Generated: 465.0 (parsed as 465.0)
# Retrieval Precision: 1.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1782:
# Question: what was the difference in percentage cumulative total shareowners 2019 returns for united parcel service inc . compared to the standard & poor's 500 index for the five years ended 12/31/2014?
# Ground Truth: 0.1874
# Generated: -0.0142 (parsed as -0.0142)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 4015:
# Question: what was the percentage change in non-cash stock-based compensation expense from 2012 to 2013?
# Ground Truth: 0.13174
# Generated: 0.25 (parsed as 0.25)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2709:
# Question: as of december 2006 what was the percent of the total future minimum lease payments for operating and capital leases that was due in 2009
# Ground Truth: 0.09033
# Generated: -0.13249 (parsed as -0.13249)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 367:
# Question: what is the growth rate of interest income from 2013 to 2014?
# Ground Truth: 0.10931
# Generated: 0.10968 (parsed as 0.10968)
# Retrieval Precision: 0.667
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 3781:
# Question: north american printing papers net sales where what percent of total printing paper sales in 2008?
# Ground Truth: 0.49927
# Generated: 0.79545 (parsed as 0.79545)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 450:
# Question: what was the percentage change in rent expenses included in selling , general and administrative expense from 2014 to 2015?
# Ground Truth: 0.40678
# Generated: 0.40678 (parsed as 0.40678)
# Retrieval Precision: 1.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 3997:
# Question: in 2009 what was the percent of the capital leases of the total future minimum lease payments that were due in 2012
# Ground Truth: 0.0523
# Generated: -0.13249 (parsed as -0.13249)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3816:
# Question: what was the 2012 effective tax rate?
# Ground Truth: 0.36056
# Generated: 0.32000 (parsed as 0.32)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 561:
# Question: with 2014 closing stock price , what is the total value of the award for the additional shares , ( in millions ) ?
# Ground Truth: 56.52358
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3361:
# Question: what was the percent of the gradual decline in the recorded amortization expense from 2006 to 2007
# Ground Truth: 0.02973
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 484:
# Question: what is the percentage of total debt from 2014-2015 that was long-term debt?
# Ground Truth: 92.50108
# Generated: 92.50108 (parsed as 92.50108)
# Retrieval Precision: 0.333
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 1233:
# Question: what is the roi of an investment in teleflex incorporated from 2013 to 2014?
# Ground Truth: 0.24
# Generated: 0.32 (parsed as 0.32)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2596:
# Question: what was the implied total value in millions of the brazilian beverage packaging joint venture , latapack-ball , in august 2010?
# Ground Truth: 457.42574
# Generated: 2500.0 (parsed as 2500.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1414:
# Question: what percentage of eurosport viewing subscribers reached were due to eurosport 2 network?
# Ground Truth: 0.64251
# Generated: 0.58423 (parsed as 0.58423)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1584:
# Question: what is the percentage change in vehicles under capital lease between 2014 and 2015?
# Ground Truth: -0.13953
# Generated: 0.21457 (parsed as 0.21457)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 4367:
# Question: what percent did cash flow from hedges reduce after reclassification?
# Ground Truth: 0.75733
# Generated: -0.16641 (parsed as -0.16641)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2533:
# Question: what was the percentage cumulative total shareholder return on pmi's common stock for the five years ended december 31 , 2017?
# Ground Truth: 0.568
# Generated: 0.32 (parsed as 0.32)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 308:
# Question: what is the growth rate in the net income from 2011 to 2012?
# Ground Truth: -0.78785
# Generated: -0.05443 (parsed as -0.05443)
# Retrieval Precision: 0.333
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1238:
# Question: what is the growth rate in advertising costs from 2006 to 2007?
# Ground Truth: 0.3358
# Generated: 0.33333 (parsed as 0.33333)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 4185:
# Question: what was the change in the total commitments to extend credit from 2016 top 2017
# Ground Truth: 0.0504
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3583:
# Question: what was the net working capital surplus for 2008 and 2009 , in millions?
# Ground Truth: 900.0
# Generated: 0.14136 (parsed as 0.14136)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1070:
# Question: in 2008 what was the tax rate associated with the goodwill impairment
# Ground Truth: 0.10345
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 759:
# Question: what was the percentage change in the employee total matching contributions from 2015 to 2016
# Ground Truth: 0.56997
# Generated: -2.1 (parsed as -2.1)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1346:
# Question: what is the growth rate in net reserves in 2006?
# Ground Truth: 0.13518
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 414:
# Question: what is the percent change in net revenue from 2003 to 2004?
# Ground Truth: 0.14738
# Generated: 0.14738 (parsed as 0.14738)
# Retrieval Precision: 1.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 495:
# Question: what percentage of total debt is from long-term debt , from 2013-2014?
# Ground Truth: 81.09151
# Generated: 0.01803 (parsed as 0.01803)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 2312:
# Question: what was the total pre-tax restructuring program cost in millions?
# Ground Truth: 257.0
# Generated: 195.0 (parsed as 195.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2009:
# Question: what is the percentage change in total current assets from 2006 to 2007?
# Ground Truth: 0.06665
# Generated: -0.56939 (parsed as -0.56939)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 688:
# Question: what is the percentage change in the balance of asset purchase agreements from 2012 to 2013?
# Ground Truth: -0.07466
# Generated: 0.03148 (parsed as 0.03148)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2808:
# Question: what was the total rent expense on all operating leases for fiscal 2008 through 2010 in millions
# Ground Truth: 93.4
# Generated: 0.1328 (parsed as 0.1328)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 2888:
# Question: what percent change did the fx impact have on the 2014 multi asset value?
# Ground Truth: -0.03656
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 465:
# Question: what is the amount of cash raised from the issuance of shares during 2015 , in millions?
# Ground Truth: 4.46367
# Generated: 0.483 (parsed as 0.483)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 2761:
# Question: what is the percent change in expected dividend yield between 2005 and 2006?
# Ground Truth: -0.0152
# Generated: 0.32 (parsed as 0.32)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 444:
# Question: what is the growth rate in operating profit for mst in 2012?
# Ground Truth: 0.14264
# Generated: 0.14 (parsed as 0.14)
# Retrieval Precision: 1.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 3155:
# Question: the total minimum payments for operating leases is what percentage of total minimum payments for capital leases?
# Ground Truth: 224.57565
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 783:
# Question: what is the percent change in net revenue between 2007 and 2008?
# Ground Truth: -0.00653
# Generated: 33.33 (parsed as 33.33)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 2043:
# Question: what is the percentage change in total gross amount of unrecognized tax benefits from 2012 to 2013?
# Ground Truth: -0.15187
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 770:
# Question: what percentage of the total purchase price was intangible assets?
# Ground Truth: 0.26604
# Generated: 8.08481 (parsed as 8.08481)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 4130:
# Question: what is the growth rate in net revenue from 2009 to 2010?
# Ground Truth: 0.12305
# Generated: 14.2 (parsed as 14.2)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3731:
# Question: what was the percentage change in free cash flow from 2006 to 2007?
# Ground Truth: -0.0562
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1515:
# Question: what was the percent of the growth of the interest expense interest expense from continuing operations increased from 2010 to 2011
# Ground Truth: 0.18294
# Generated: 0.47419 (parsed as 0.47419)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1256:
# Question: what is the percentage change in the balance of currency and commodities from 2011 to 2012?
# Ground Truth: 0.00307
# Generated: 0.04618 (parsed as 0.04618)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 282:
# Question: what was the percentage change in revenues between 2005 and 2006?
# Ground Truth: 0.45308
# Generated: 0.50000 (parsed as 0.5)
# Retrieval Precision: 0.333
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2070:
# Question: what percent of distribution sales where attributable to printing papers and graphic arts supplies and equipment in 2011?
# Ground Truth: 0.60332
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2154:
# Question: what was the percentage change in the pre-tax catastrophe losses from 2015 to 2016
# Ground Truth: 4.59851
# Generated: -0.1135 (parsed as -0.1135)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1261:
# Question: what is the growth rate in pre-tax earnings in 2011?
# Ground Truth: -0.34681
# Generated: 31.0 (parsed as 31.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 2751:
# Question: what was the percentage change in operating profits in 2015
# Ground Truth: 0.05085
# Generated: -5.443 (parsed as -5.443)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 622:
# Question: what is the growth rate in the total expense related to the defined contribution plan for non-u.s.employees in 2011?
# Ground Truth: 0.82906
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 948:
# Question: what is the growth rate in operating profit from 2012 to 2013 for is&gs?
# Ground Truth: -0.06064
# Generated: -0.06 (parsed as -0.06)
# Retrieval Precision: 0.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 3536:
# Question: in 2008 what was the percentage increased in the mezzanine capital facility
# Ground Truth: 0.28571
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2507:
# Question: what is the growth rate in net sales for mfc in 2012?
# Ground Truth: -0.0008
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 4356:
# Question: what was the percentage increase in the income from financial investments net ( note e ) from 2009 to 2010
# Ground Truth: 2.0
# Generated: 0.24446 (parsed as 0.24446)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3776:
# Question: what is the percent change in net revenue from 2015 to 2016?
# Ground Truth: 0.06004
# Generated: -11.349 (parsed as -11.349)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 360:
# Question: what is actual operating cash flow reported for 2011?
# Ground Truth: 3.34978
# Generated: 0.0192 (parsed as 0.0192)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1242:
# Question: what is the total amount reported in issuance of shares for employee benefit plans in the last three years , ( in millions ) ?
# Ground Truth: 517.0
# Generated: 27.0 (parsed as 27.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3433:
# Question: for the quarter ended june 30 what was the percentage change in the share price from he lowest to the highest
# Ground Truth: 0.43756
# Generated: 0.32 (parsed as 0.32)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2791:
# Question: what is the percentage change in discounted liabilities from 2013 to 2014?
# Ground Truth: -0.04054
# Generated: -0.11349 (parsed as -0.11349)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 66:
# Question: what was the 5 year return of the kbw bank index?
# Ground Truth: 1.5882
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3427:
# Question: what is the percentage change in annual operating cash flow from 2009 to 2010?
# Ground Truth: 0.8304
# Generated: 0.01919 (parsed as 0.01919)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2178:
# Question: what percentage change in rent expense from 2015 to 2016?
# Ground Truth: 0.31325
# Generated: -0.02778 (parsed as -0.02778)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 4158:
# Question: what was the percent of the change in the weighted average grant date fair value per share of restricted stock from 2016 to 2017
# Ground Truth: 0.15478
# Generated: 68.5 (parsed as 68.5)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1078:
# Question: by how much did the average price per share decrease from 2007 to 2009?
# Ground Truth: -0.22954
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3224:
# Question: what was the percentage change in the accretable yield activity for the firm 2019s pci consumer loans in 2010
# Ground Truth: -0.25239
# Generated: 0.17647 (parsed as 0.17647)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3655:
# Question: what portion of the securities approved by security holders remains available for future issuance?
# Ground Truth: 0.79884
# Generated: 0.151 (parsed as 0.151)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1737:
# Question: what is the percentage change in net cash from operating activities from 2011 to 2012?
# Ground Truth: -0.01982
# Generated: 0.0191 (parsed as 0.0191)
# Retrieval Precision: 0.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 3613:
# Question: what was the percentage change in the asian consumer packaging net sales in 2013
# Ground Truth: -0.99867
# Generated: 0.67385 (parsed as 0.67385)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 4286:
# Question: based on the table , how much percent did the healthcare sector outperform the overall market in this 5 year period?
# Ground Truth: 18.0
# Generated: 0.0228 (parsed as 0.0228)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 2458:
# Question: if stock compensation were not an expense , what would 2015 net income have been?
# Ground Truth: 434300000.0
# Generated: 98.0 (parsed as 98.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 4065:
# Question: considering the years 2021-2025 , what is the difference between the average projected benefit payments for the u.s . and international?
# Ground Truth: 117.12
# Generated: -0.19355 (parsed as -0.19355)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3625:
# Question: what are the total pre-tax catastrophe losses for the company in the last three years?\\n
# Ground Truth: 1827.6
# Generated: 1905.4 (parsed as 1905.4)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1840:
# Question: what is the percentage change in weighted average common shares outstanding for diluted computations from 2015 to 2016?
# Ground Truth: -0.03686
# Generated: 22.77778 (parsed as 22.77778)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 577:
# Question: what was the total number , in mmboe , of 2014 proved developed reserves?
# Ground Truth: 700.0
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3233:
# Question: by how much did the allowance for doubtful accounts increase from 2005 to 2006?
# Ground Truth: 0.13043
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1143:
# Question: what is the percentage change in aggregate notional amount of outstanding interest rate swaps from 2011 to 2012?
# Ground Truth: 0.11778
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3787:
# Question: what is the total rent expense for the period from december 31 , 2017 , 2016 and 2015 in millions
# Ground Truth: 22.9
# Generated: 24.0 (parsed as 24.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3754:
# Question: what is the percent change in net revenue between 2007 and 2008?
# Ground Truth: -0.03219
# Generated: 33.33 (parsed as 33.33)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3902:
# Question: what was the percentage change in net sales from 2001 to 2002?
# Ground Truth: 0.07067
# Generated: -0.0750 (parsed as -0.075)
# Retrieval Precision: 0.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 2669:
# Question: how much did the cost of sales change over from 2010 to 2012
# Ground Truth: -28933.0
# Generated: 0.8 (parsed as 0.8)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3266:
# Question: what is the percentage change in the number of staff in 2012?
# Ground Truth: -0.02703
# Generated: -0.25 (parsed as -0.25)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 191:
# Question: what is the roi of an investment in the o'reilly automotive inc . from 2010 to 2011?
# Ground Truth: 0.32
# Generated: 0.32 (parsed as 0.32)
# Retrieval Precision: 1.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 3336:
# Question: what was the percent of the change in the non-vested performance awards at end of year
# Ground Truth: -0.25147
# Generated: 68.5 (parsed as 68.5)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3855:
# Question: what is the growth rate in the balance of asset allocation from 2014 to 2015?
# Ground Truth: 0.01532
# Generated: 0.42 (parsed as 0.42)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2017:
# Question: what was the percent of the decline in the mst net sales from 2010 to 2011
# Ground Truth: -0.04178
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2666:
# Question: what is the percentage change in risk-free interest rate from 2007 to 2008?
# Ground Truth: -0.30155
# Generated: 0.1249 (parsed as 0.1249)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2585:
# Question: what is the percentage change in the balance of unrecognized tax benefits during 2007?
# Ground Truth: 0.03627
# Generated: 0.83648 (parsed as 0.83648)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3499:
# Question: what was the difference in percentage return for lilly compared to the s&p 500 for the five years ended dec-18?
# Ground Truth: 1.0955
# Generated: 0.0228 (parsed as 0.0228)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 311:
# Question: what is the percentage change in the weight of smokeless products in operating income from 2015 to 2016?
# Ground Truth: 0.02344
# Generated: 2.344 (parsed as 2.344)
# Retrieval Precision: 1.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 858:
# Question: for how many common stock shares did the company pay dividends in 2012 , ( in millions ) ?
# Ground Truth: 1251.42857
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3502:
# Question: based solely on cash for towers acquisitions , what was the average cost per tower acquired in 2005-2007?
# Ground Truth: 200000.0
# Generated: 27.0 (parsed as 27.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2253:
# Question: what was the percentage change in operating income from 2005 to 2006?
# Ground Truth: 1.4463
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 2347:
# Question: what was the percentage of the real estate portfolios for asia from 2014 to 2015
# Ground Truth: 0.49359
# Generated: 0.00000 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 441:
# Question: what is the percentage difference in the number of shares to be issued if the stock price closes at $ 11 compared to if it closes at $ 20?
# Ground Truth: 22.77778
# Generated: 22.77778 (parsed as 22.77778)
# Retrieval Precision: 1.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 14:
# Question: what was the percentage change in net sales from 2000 to 2001?
# Ground Truth: -0.3282
# Generated: -32.82 (parsed as -32.82)
# Retrieval Precision: 1.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1473:
# Question: considering the properties with lease expiration dates in 2020 , what is the average occupied square footage?
# Ground Truth: 389000.0
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3819:
# Question: based on the summary of the restricted stock and performance shares activity for 2010 what was percentage change in the number of shares outstanding
# Ground Truth: 0.68381
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2079:
# Question: what is the estimated percentual increase observed in the class a common stock during the years 2009 and 2010?
# Ground Truth: 0.00505
# Generated: 5.0208 (parsed as 5.0208)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 4359:
# Question: what is the principal payment in 2017 as a percentage of the total senior secured transition bonds?
# Ground Truth: 0.08376
# Generated: 0.08118 (parsed as 0.08118)
# Retrieval Precision: 0.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 2192:
# Question: what is the average percent of lifo inventories as a percent of consolidated inventories as of december 31 , 2015 and 2014?
# Ground Truth: 38.0
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2120:
# Question: what was the total purchase price in cash payment for the sentinelle medical acquisition?
# Ground Truth: 834.8
# Generated: 47.1 (parsed as 47.1)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1161:
# Question: what was the decrease observed in the sales during 2013 and 2014?
# Ground Truth: -0.83748
# Generated: 417471.0 (parsed as 417471.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1820:
# Question: what was the percentage change in cash from operating activities from 2009 to 2010?
# Ground Truth: -0.02602
# Generated: 0.01919 (parsed as 0.01919)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3006:
# Question: what was the average price per share , in dollars , of the stock the company sold in august 2006?
# Ground Truth: 14.30757
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 2038:
# Question: what was the percentage change in accrued wages and vacation from 2011 to 2012?
# Ground Truth: 0.03581
# Generated: 12.0 (parsed as 12.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3109:
# Question: what was average weighted average useful life ( years ) for customer contracts and relationships and trademarks?
# Ground Truth: 8.5
# Generated: 9.0 (parsed as 9.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3589:
# Question: what was the average other income from 2004 to 2006 in millions
# Ground Truth: 117.0
# Generated: 315.0 (parsed as 315.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2065:
# Question: what was the average crack spread for us gulf coast lls 6-3-2-1 in the first and second quarter of 2008?
# Ground Truth: 1.69
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3256:
# Question: what is the rate of return of an investment in ups from 2003 to 2004?
# Ground Truth: 0.16398
# Generated: -8.94 (parsed as -8.94)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 778:
# Question: what is the mark-to-market as a percentage of the decrease in net revenue from 2012 to 2013?
# Ground Truth: 1.11538
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 509:
# Question: what is the total value of repurchased shares during october 2012 , in millions?
# Ground Truth: 78.66751
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 839:
# Question: what is the growth rate in net sales for walmart u.s . segment from 2017 to 2018?
# Ground Truth: 0.03458
# Generated: 0.97833 (parsed as 0.97833)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2219:
# Question: what is the $ 500.0 million in principal paid in 2015 as a percentage of the $ 2.5 billion in outstanding borrowings?
# Ground Truth: 0.2
# Generated: 20.0 (parsed as 20.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2141:
# Question: what is the net change in cash for 2017?
# Ground Truth: -319.3
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 349:
# Question: what is the short-term debt as a percent of long-term debt , in 2019?
# Ground Truth: 0.01803
# Generated: 153.0 (parsed as 153.0)
# Retrieval Precision: 1.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 972:
# Question: what was the percentage change in equipment rents payable from 2011 to 2012?
# Ground Truth: 0.05556
# Generated: 0.21457 (parsed as 0.21457)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 178:
# Question: what is the growth rate in the average price of the purchased shares from october to november 2014?
# Ground Truth: 0.06092
# Generated: 0.06092 (parsed as 0.06092)
# Retrieval Precision: 1.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 392:
# Question: what is the growth rate in net sales for is&gs in 2011?
# Ground Truth: -0.05443
# Generated: -0.06000 (parsed as -0.06)
# Retrieval Precision: 1.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3250:
# Question: what is the total of the company 2019s future minimum revenues under the terms of all non-cancelable tenant sublease from 2009-2011 , in millions?\\n
# Ground Truth: 15.5
# Generated: 34.0 (parsed as 34.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1459:
# Question: what was the percentage increase in the cash provided by operating activities from 2015 to 2016
# Ground Truth: 0.02465
# Generated: 0.11546 (parsed as 0.11546)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 252:
# Question: what was the percentage change in rental expenses from 2017 to 2018?
# Ground Truth: 0.21457
# Generated: 0.40678 (parsed as 0.40678)
# Retrieval Precision: 0.333
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1727:
# Question: 2012 debt maturities is what percent higher than the next highest year ( 2011 ) ?
# Ground Truth: 3.04011
# Generated: 3401.0 (parsed as 3401.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 403:
# Question: what is the percentage change in nonrecurring losses from 2012 to 2013?
# Ground Truth: 0.11765
# Generated: -0.11349 (parsed as -0.11349)
# Retrieval Precision: 0.667
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2448:
# Question: what is the total value of granted options in 2006 , in millions?
# Ground Truth: 71.3974
# Generated: 0.70067 (parsed as 0.70067)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 3966:
# Question: based on the summary of changes in mortgage repurchase liability what was the percent of the change in the repurchase liability
# Ground Truth: -0.59618
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 4120:
# Question: in 2009 what was the percentage of the total loans sold that was from commercial mortagages
# Ground Truth: 0.22353
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1887:
# Question: what is the percentage change in 401 ( k ) contributions from 2001 to 2002?
# Ground Truth: -0.36429
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 2093:
# Question: what is the percentage change in net cash from operating activities from 2010 to 2011?
# Ground Truth: 0.47075
# Generated: 0.0192 (parsed as 0.0192)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 919:
# Question: what was the percentage decline in the operating earnings in 2007 of $ 37 million declined from $ 41
# Ground Truth: -0.09756
# Generated: 9.7561 (parsed as 9.7561)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 1281:
# Question: what percentage where brazilian papers net sales of printing papers sales in 2014?
# Ground Truth: 0.19231
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1922:
# Question: what was the percentage increase in the allowance in doubtful accounts from 2009 to 2010
# Ground Truth: 0.15625
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 975:
# Question: how many shares received dividends during 2014 , ( in millions ) ?
# Ground Truth: 1217.5
# Generated: 14.9 (parsed as 14.9)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 2550:
# Question: what was the percentage increase of capital expenditures for operations in the industrial packaging business segment in from 2017 to 2018?
# Ground Truth: 0.26914
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 45:
# Question: what portion of total obligations are due within the next 3 years?
# Ground Truth: 0.22986
# Generated: 0.57656 (parsed as 0.57656)
# Retrieval Precision: 0.333
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1540:
# Question: what was the percentage change in the net sales in asian papers from 2006 to 2007
# Ground Truth: 0.33333
# Generated: 0.79545 (parsed as 0.79545)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 3659:
# Question: what is the percentage increase in obligation for the mrrp from 2011 to 2012?
# Ground Truth: 0.05093
# Generated: -0.05443 (parsed as -0.05443)
# Retrieval Precision: 0.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 1303:
# Question: what is the growth rate of revenue from 2009 to 2010?
# Ground Truth: 0.01872
# Generated: 0.1413 (parsed as 0.1413)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 4019:
# Question: what is the growth rate in operating profit for aeronautics in 2013?
# Ground Truth: -0.05121
# Generated: 0.0 (parsed as 0.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 765:
# Question: what is the growth rate in net revenues in 2018?
# Ground Truth: 0.11873
# Generated: 0.00116 (parsed as 0.00116)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------
#
# Example 1764:
# Question: by what percentage did the average price of wti crude oil increase from 2010 to 2012?
# Ground Truth: 0.18264
# Generated: 2247.0 (parsed as 2247.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.000, ROUGE-2: 0.000, ROUGE-L: 0.000
# ----------
#
# Example 241:
# Question: what are the total pre-tax catastrophe losses in the last three years?
# Ground Truth: 1905.4
# Generated: 1905.4 (parsed as 1905.4)
# Retrieval Precision: 1.000
# ROUGE-1: 1.000, ROUGE-2: 1.000, ROUGE-L: 1.000
# ----------
#
# Example 618:
# Question: what is the approximate customer penetration for the total regulated businesses?
# Ground Truth: 36003776400000.0
# Generated: 19870.0 (parsed as 19870.0)
# Retrieval Precision: 0.000
# ROUGE-1: 0.500, ROUGE-2: 0.000, ROUGE-L: 0.500
# ----------

# %%
accuracy = total_correct / num_evaluated if num_evaluated > 0 else 0.0
avg_retrieval_precision = total_retrieval_precision / num_evaluated if num_evaluated > 0 else 0.0
avg_rouge1 = total_rouge1 / num_evaluated if num_evaluated > 0 else 0.0
avg_rouge2 = total_rouge2 / num_evaluated if num_evaluated > 0 else 0.0
avg_rougeL = total_rougeL / num_evaluated if num_evaluated > 0 else 0.0

print("Evaluation Metrics:")
print(f"Accuracy (Exact Match within tolerance): {accuracy:.3f}")
print(f"Average Retrieval Precision: {avg_retrieval_precision:.3f}")
print(f"Average ROUGE-1: {avg_rouge1:.3f}")
print(f"Average ROUGE-2: {avg_rouge2:.3f}")
print(f"Average ROUGE-L: {avg_rougeL:.3f}")
# Out:
# Evaluation Metrics:
# Accuracy (Exact Match within tolerance): 0.063
# Average Retrieval Precision: 0.105
# Average ROUGE-1: 0.371
# Average ROUGE-2: 0.105
# Average ROUGE-L: 0.371

# %% [markdown]
# ### 9. Test the Generate answe function on a single query and execute turn program
# ---

# %%
test_query = "what is the net cash from operating activities in 2009?"
test_retrieved = query_dataset(test_query, top_n=3)
test_context_docs = test_retrieved['chunk_text'].tolist()
test_generated_answer = generate_answer(test_query, test_context_docs, max_tokens=200, temperature=0.0, top_p=1.0)
print("\nTest Generated Answer for query:")
print(f"Question: {test_query}")
print(f"Generated Answer: {test_generated_answer}")
# Out:
# Test Generated Answer for query:
# Question: what is the net cash from operating activities in 2009?
# Generated Answer: 206588.0

# %%
# Additionally, attempt to execute the turn program from the top retrieved document, if available.
top_doc_id = test_retrieved.iloc[0]['doc_id']
# Retrieve the original example from the full dataframe
top_example = df[df['id'] == top_doc_id].iloc[0]
if 'turn_program' in top_example and pd.notnull(top_example['turn_program']):
    cur_program = top_example['turn_program']
    print("\nRetrieved 'turn_program' for execution:")
    print(cur_program)
    try:
        executed_answer = eval(cur_program)
        print("Executed Answer:", executed_answer)
    except Exception as e:
        print("Error executing turn_program:", e)
else:
    print("No 'turn_program' available for the selected example.")
# Out:
# Retrieved 'turn_program' for execution:
# 206588
# Executed Answer: 206588
